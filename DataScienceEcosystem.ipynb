# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Author
# Peter Thomson

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives**
# - List popular langauges for Data Science
# - List popular libraries for Data Science
# - List common tools used for Data Science
# - Evaluate some basic arithmetic in Python code cells

# %% [markdown]
# Some of popular popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Scikit-learn
# 2. Matplotlib
# 3. Numpy
# 4. caret
# 5. ggplot

# %% [markdown]
# | Data Science Tools|
# |----|
# |Visual Studio Code|
# |R Studio |
# |Jupyter Lab|
# |Jupyter Notebook|
# |Jupyter Lite|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to multiply and then add integers
(3*4) + 5
# Out:
# 17

# %%
# This code cell will convert 200 minutes into a number of hours
200 / 60
# Out:
# 3.3333333333333335
